# %%
import requests
import json

key = 'GK%2Bl5QlLpGSK9H3bruybzUiF%2BVA6xAMnyRYYaj8taJMMCFeqxwyCXCrby0aU9WnsaX8XmxzQrvU5mRBIrYLTMA%3D%3D'
# decode_key = requests.utils.unquote(key)

response = requests.get('http://apis.data.go.kr/1360000/TourStnInfoService/getTourStnVilageFcst\
# ?serviceKey={}\
&numOfRows=10&pageNo=1&dataType=JSON&CURRENT_DATE=2020080601&HOUR=24&COURSE_ID=3'.format(key))
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":203,"spotAreaName":"영동","spotName":"(영동)송호국민관광지캠핑장","th3":23,"thema":"캠핑/스포츠","tm":"2020-08-08 00:00","wd":171,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":203,"spotAreaName":"영동","spotName":"(영동)송호국민관광지캠핑장","th3":23,"thema":"종교/역사/전통","tm":"2020-08-08 00:00","wd":171,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":201,"spotAreaName":"영동","spotName":"(영동)영국사","th3":23,"thema":"종교/역사/전통","tm":"2020-08-08 00:00","wd":171,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":201,"spotAreaName":"영동","spotName":"(영동)영국사","th3":23,"thema":"캠핑/스포츠","tm":"2020-08-08 00:00","wd":171,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":202,"spotAreaName":"영동","spotName":"(영동)난계국악박물관/난계국악기체험전수관","th3":23,"thema":"캠핑/스포츠","tm":"2020-08-08 00:00","wd":169,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":202,"spotAreaName":"영동","spotName":"(영동)난계국악박물관/난계국악기체험전수관","th3":23,"thema":"종교/역사/전통","tm":"2020-08-08 00:00","wd":169,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":201,"spotAreaName":"영동","spotName":"(영동)영국사","th3":23,"thema":"종교/역사/전통","tm":"2020-08-07 21:00","wd":164,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":201,"spotAreaName":"영동","spotName":"(영동)영국사","th3":23,"thema":"캠핑/스포츠","tm":"2020-08-07 21:00","wd":164,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":202,"spotAreaName":"영동","spotName":"(영동)난계국악박물관/난계국악기체험전수관","th3":23,"thema":"캠핑/스포츠","tm":"2020-08-07 21:00","wd":150,"ws":0},{"courseAreaId":"4300000000","courseAreaName":"충청북도","courseId":"2","courseName":"천년의 비밀을 지닌 고찰에서 캠핑을 하다","pop":80,"rhm":95,"sky":5,"spotAreaId":202,"spotAreaName":"영동","spotName":"(영동)난계국악박물관/난계국악기체험전수관","th3":23,"thema":"종교/역사/전통","tm":"2020-08-07 21:00","wd":150,"ws":0}]},"pageNo":1,"numOfRows":10,"totalCount":96}}}'

# %%
data=json.loads(response.text)
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 302,
#       'spotAreaName': '영양',
#       'spotName': '(영양)두메송하마을',
#       'th3': 21,
#       'thema': '쇼핑/놀이',
#       'tm': '2020-08-08 00:00',
#       'wd': 328,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 304,
#       'spotAreaName': '영양',
#       'spotName': '(영양)국립 검마산자연휴양림',
#       'th3': 21,
#       'thema': '체험/학습/산업',
#       'tm': '2020-08-08 00:00',
#       'wd': 328,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 304,
#       'spotAreaName': '영양',
#       'spotName': '(영양)국립 검마산자연휴양림',
#       'th3': 21,
#       'thema': '자연/힐링',
#       'tm': '2020-08-08 00:00',
#       'wd': 328,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 303,
#       'spotAreaName': '영양',
#       'spotName': '(영양)영양시장',
#       'th3': 21,
#       'thema': '쇼핑/놀이',
#       'tm': '2020-08-08 00:00',
#       'wd': 324,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 303,
#       'spotAreaName': '영양',
#       'spotName': '(영양)영양시장',
#       'th3': 21,
#       'thema': '체험/학습/산업',
#       'tm': '2020-08-08 00:00',
#       'wd': 324,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 303,
#       'spotAreaName': '영양',
#       'spotName': '(영양)영양시장',
#       'th3': 21,
#       'thema': '자연/힐링',
#       'tm': '2020-08-08 00:00',
#       'wd': 324,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 304,
#       'spotAreaName': '영양',
#       'spotName': '(영양)국립 검마산자연휴양림',
#       'th3': 21,
#       'thema': '쇼핑/놀이',
#       'tm': '2020-08-08 00:00',
#       'wd': 328,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 302,
#       'spotAreaName': '영양',
#       'spotName': '(영양)두메송하마을',
#       'th3': 21,
#       'thema': '체험/학습/산업',
#       'tm': '2020-08-08 00:00',
#       'wd': 328,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 302,
#       'spotAreaName': '영양',
#       'spotName': '(영양)두메송하마을',
#       'th3': 21,
#       'thema': '자연/힐링',
#       'tm': '2020-08-08 00:00',
#       'wd': 328,
#       'ws': 0},
#      {'courseAreaId': '4700000000',
#       'courseAreaName': '경상북도',
#       'courseId': '3',
#       'courseName': '밝고 청정한 영양의 산천을 찾아서',
#       'pop': 80,
#       'rhm': 100,
#       'sky': 5,
#       'spotAreaId': 301,
#       'spotAreaName': '영양',
#       'spotName': '(영양)일월산',
#       'th3': 18,
#       'thema': '쇼핑/놀이',
#       'tm': '2020-08-08 00:00',
#       'wd': 315,
#       'ws': 1}]},
#    'pageNo': 1,
#    'numOfRows': 10,
#    'totalCount': 192}}}

# %%
a = data['response']['body']['items']['item']

print(len(a))
a
# Out:
# 10
# [{'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 302,
#   'spotAreaName': '영양',
#   'spotName': '(영양)두메송하마을',
#   'th3': 21,
#   'thema': '쇼핑/놀이',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 304,
#   'spotAreaName': '영양',
#   'spotName': '(영양)국립 검마산자연휴양림',
#   'th3': 21,
#   'thema': '체험/학습/산업',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 304,
#   'spotAreaName': '영양',
#   'spotName': '(영양)국립 검마산자연휴양림',
#   'th3': 21,
#   'thema': '자연/힐링',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 303,
#   'spotAreaName': '영양',
#   'spotName': '(영양)영양시장',
#   'th3': 21,
#   'thema': '쇼핑/놀이',
#   'tm': '2020-08-08 00:00',
#   'wd': 324,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 303,
#   'spotAreaName': '영양',
#   'spotName': '(영양)영양시장',
#   'th3': 21,
#   'thema': '체험/학습/산업',
#   'tm': '2020-08-08 00:00',
#   'wd': 324,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 303,
#   'spotAreaName': '영양',
#   'spotName': '(영양)영양시장',
#   'th3': 21,
#   'thema': '자연/힐링',
#   'tm': '2020-08-08 00:00',
#   'wd': 324,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 304,
#   'spotAreaName': '영양',
#   'spotName': '(영양)국립 검마산자연휴양림',
#   'th3': 21,
#   'thema': '쇼핑/놀이',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 302,
#   'spotAreaName': '영양',
#   'spotName': '(영양)두메송하마을',
#   'th3': 21,
#   'thema': '체험/학습/산업',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 302,
#   'spotAreaName': '영양',
#   'spotName': '(영양)두메송하마을',
#   'th3': 21,
#   'thema': '자연/힐링',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 301,
#   'spotAreaName': '영양',
#   'spotName': '(영양)일월산',
#   'th3': 18,
#   'thema': '쇼핑/놀이',
#   'tm': '2020-08-08 00:00',
#   'wd': 315,
#   'ws': 1}]

# %%
a
# Out:
# [{'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 302,
#   'spotAreaName': '영양',
#   'spotName': '(영양)두메송하마을',
#   'th3': 21,
#   'thema': '쇼핑/놀이',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 304,
#   'spotAreaName': '영양',
#   'spotName': '(영양)국립 검마산자연휴양림',
#   'th3': 21,
#   'thema': '체험/학습/산업',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 304,
#   'spotAreaName': '영양',
#   'spotName': '(영양)국립 검마산자연휴양림',
#   'th3': 21,
#   'thema': '자연/힐링',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 303,
#   'spotAreaName': '영양',
#   'spotName': '(영양)영양시장',
#   'th3': 21,
#   'thema': '쇼핑/놀이',
#   'tm': '2020-08-08 00:00',
#   'wd': 324,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 303,
#   'spotAreaName': '영양',
#   'spotName': '(영양)영양시장',
#   'th3': 21,
#   'thema': '체험/학습/산업',
#   'tm': '2020-08-08 00:00',
#   'wd': 324,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 303,
#   'spotAreaName': '영양',
#   'spotName': '(영양)영양시장',
#   'th3': 21,
#   'thema': '자연/힐링',
#   'tm': '2020-08-08 00:00',
#   'wd': 324,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 304,
#   'spotAreaName': '영양',
#   'spotName': '(영양)국립 검마산자연휴양림',
#   'th3': 21,
#   'thema': '쇼핑/놀이',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 302,
#   'spotAreaName': '영양',
#   'spotName': '(영양)두메송하마을',
#   'th3': 21,
#   'thema': '체험/학습/산업',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 302,
#   'spotAreaName': '영양',
#   'spotName': '(영양)두메송하마을',
#   'th3': 21,
#   'thema': '자연/힐링',
#   'tm': '2020-08-08 00:00',
#   'wd': 328,
#   'ws': 0},
#  {'courseAreaId': '4700000000',
#   'courseAreaName': '경상북도',
#   'courseId': '3',
#   'courseName': '밝고 청정한 영양의 산천을 찾아서',
#   'pop': 80,
#   'rhm': 100,
#   'sky': 5,
#   'spotAreaId': 301,
#   'spotAreaName': '영양',
#   'spotName': '(영양)일월산',
#   'th3': 18,
#   'thema': '쇼핑/놀이',
#   'tm': '2020-08-08 00:00',
#   'wd': 315,
#   'ws': 1}]
